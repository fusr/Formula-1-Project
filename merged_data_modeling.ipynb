# %%
# importing
import pandas as pd

# %%
tyre_data = pd.read_csv("data/tyre_data_drRef.csv")

# %%
tyre_data.head()
# Out:
#    Unnamed: 0            Driver         GP       Tyres  From  To  #Laps  year
# 0           0     Jenson Button  Australia   Soft Used     1  16     16  2012  \
# 1           1     Jenson Button  Australia  Medium New    17  36     20  2012
# 2           2     Jenson Button  Australia  Medium New    37  58     22  2012
# 3           3  Sebastian Vettel  Australia   Soft Used     1  16     16  2012
# 4           4  Sebastian Vettel  Australia   Soft Used    17  37     21  2012
#
#    location  raceId  driverId driverRef
# 0  Adelaide     860      18.0    button
# 1  Adelaide     860      18.0    button
# 2  Adelaide     860      18.0    button
# 3  Adelaide     860      20.0    vettel
# 4  Adelaide     860      20.0    vettel

# %%
tyre_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13302 entries, 0 to 13301
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  13302 non-null  int64
#  1   Driver      13297 non-null  object
#  2   GP          13302 non-null  object
#  3   Tyres       13302 non-null  object
#  4   From        13302 non-null  int64
#  5   To          13302 non-null  int64
#  6   #Laps       13302 non-null  int64
#  7   year        13302 non-null  int64
#  8   location    11353 non-null  object
#  9   raceId      13302 non-null  int64
#  10  driverId    13164 non-null  float64
#  11  driverRef   13297 non-null  object
# dtypes: float64(1), int64(6), object(5)
# memory usage: 1.2+ MB

# %%
tyre_data.Tyres.unique()
# Out:
# array(['Soft Used', 'Medium New', 'Soft New', 'Medium Used',
#        'Intermediate New', 'Wet New', 'Hard New', 'Intermediate Used',
#        'Lluvia Extrema Usado', 'Hard Used', 'Supersoft Used',
#        'Supersoft New', 'Ultrasoft New', 'Ultrasoft Used',
#        'Hiper Blando Usado', 'Hiper Blando Nuevo'], dtype=object)

# %%
# Define a dictionary to map old values to new values
tyres_mapping = {
    'Hiper Blando Usado': 'Hyper Soft',
    'Hiper Blando Nuevo': 'Hyper Soft',
    'Lluvia Extrema Usado': 'Full Wet'
}

# Use the replace() method to update the values in the "tyres" column
tyre_data['Tyres'] = tyre_data['Tyres'].replace(tyres_mapping)

# %%
# Remove " Used" and " New" from the 'tyres' column
tyre_data['Tyres'] = tyre_data['Tyres'].str.replace(' Used', '').str.replace(' New', '')

# Print the DataFrame to verify the changes
print(tyre_data)
# Out:
#        Unnamed: 0            Driver           GP         Tyres  From  To
# 0               0     Jenson Button    Australia          Soft     1  16  \
# 1               1     Jenson Button    Australia        Medium    17  36
# 2               2     Jenson Button    Australia        Medium    37  58
# 3               3  Sebastian Vettel    Australia          Soft     1  16
# 4               4  Sebastian Vettel    Australia          Soft    17  37
# ...           ...               ...          ...           ...   ...  ..
# 13297       13297       Zhou Guanyu  Netherlands          Soft    38  60
# 13298       13298    Logan Sargeant  Netherlands          Soft     1  14
# 13299       13299    Max Verstappen  Netherlands  Intermediate    65  72
# 13300       13300      Pierre Gasly  Netherlands          Soft    47  60
# 13301       13301   Nico Hulkenberg  Netherlands        Medium    17  48
#
#        #Laps  year   location  raceId  driverId   driverRef
# ...

# %%
tyre_data.Tyres.unique()
# Out:
# array(['Soft', 'Medium', 'Intermediate', 'Wet', 'Hard', 'Full Wet',
#        'Supersoft', 'Ultrasoft', 'Hyper Soft'], dtype=object)

# %%
# Drop the "Unnamed: 0" column
tyre_data.drop('Unnamed: 0', axis=1, inplace=True)

tyre_data.head()
# Out:
#              Driver         GP   Tyres  From  To  #Laps  year  location
# 0     Jenson Button  Australia    Soft     1  16     16  2012  Adelaide  \
# 1     Jenson Button  Australia  Medium    17  36     20  2012  Adelaide
# 2     Jenson Button  Australia  Medium    37  58     22  2012  Adelaide
# 3  Sebastian Vettel  Australia    Soft     1  16     16  2012  Adelaide
# 4  Sebastian Vettel  Australia    Soft    17  37     21  2012  Adelaide
#
#    raceId  driverId driverRef
# 0     860      18.0    button
# 1     860      18.0    button
# 2     860      18.0    button
# 3     860      20.0    vettel
# 4     860      20.0    vettel

# %%
races_with_dummies_df = pd.read_csv("data/races_with_dummies.csv")

# %%
races_with_dummies_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1102 entries, 0 to 1101
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   raceId            1102 non-null   int64
#  1   year              1102 non-null   int64
#  2   round             1102 non-null   int64
#  3   circuitId         1102 non-null   int64
#  4   name              1102 non-null   object
#  5   date              1102 non-null   object
#  6   time              1102 non-null   object
#  7   url               1102 non-null   object
#  8   fp1_date          1102 non-null   object
#  9   fp1_time          1102 non-null   object
#  10  fp2_date          1102 non-null   object
#  11  fp2_time          1102 non-null   object
#  12  fp3_date          1102 non-null   object
#  13  fp3_time          1102 non-null   object
#  14  quali_date        1102 non-null   object
#  15  quali_time        1102 non-null   object
# ...

# %%
races_with_dummies_df.head()
# Out:
#    raceId  year  round  circuitId                   name        date
# 0       1  2009      1          1  Australian Grand Prix  2009-03-29  \
# 1       2  2009      2          2   Malaysian Grand Prix  2009-04-05
# 2       3  2009      3         17     Chinese Grand Prix  2009-04-19
# 3       4  2009      4          3     Bahrain Grand Prix  2009-04-26
# 4       5  2009      5          4     Spanish Grand Prix  2009-05-10
#
#        time                                                url fp1_date
# 0  06:00:00  http://en.wikipedia.org/wiki/2009_Australian_G...       \N  \
# 1  09:00:00  http://en.wikipedia.org/wiki/2009_Malaysian_Gr...       \N
# 2  07:00:00  http://en.wikipedia.org/wiki/2009_Chinese_Gran...       \N
# 3  12:00:00  http://en.wikipedia.org/wiki/2009_Bahrain_Gran...       \N
# 4  12:00:00  http://en.wikipedia.org/wiki/2009_Spanish_Gran...       \N
#
#   fp1_time  ... quali_time sprint_date sprint_time weather_category
# ...

# %%
circuits_df = pd.read_csv("data/circuits.csv")

# %%
circuits_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   circuitId   77 non-null     int64
#  1   circuitRef  77 non-null     object
#  2   name        77 non-null     object
#  3   location    77 non-null     object
#  4   country     77 non-null     object
#  5   lat         77 non-null     float64
#  6   lng         77 non-null     float64
#  7   alt         77 non-null     object
#  8   url         77 non-null     object
# dtypes: float64(2), int64(1), object(6)
# memory usage: 5.5+ KB

# %%
circuits_df.head()
# Out:
#    circuitId   circuitRef                            name      location
# 0          1  albert_park  Albert Park Grand Prix Circuit     Melbourne  \
# 1          2       sepang    Sepang International Circuit  Kuala Lumpur
# 2          3      bahrain   Bahrain International Circuit        Sakhir
# 3          4    catalunya  Circuit de Barcelona-Catalunya      Montmeló
# 4          5     istanbul                   Istanbul Park      Istanbul
#
#      country       lat        lng  alt
# 0  Australia -37.84970  144.96800   10  \
# 1   Malaysia   2.76083  101.73800   18
# 2    Bahrain  26.03250   50.51060    7
# 3      Spain  41.57000    2.26111  109
# 4     Turkey  40.95170   29.40500  130
#
#                                                  url
# 0  http://en.wikipedia.org/wiki/Melbourne_Grand_P...
# 1  http://en.wikipedia.org/wiki/Sepang_Internatio...
# 2  http://en.wikipedia.org/wiki/Bahrain_Internati...
# 3  http://en.wikipedia.org/wiki/Circuit_de_Barcel...
# ...

# %%
results_df = pd.read_csv("data/results.csv")

# %%
results_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25840 entries, 0 to 25839
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   resultId         25840 non-null  int64
#  1   raceId           25840 non-null  int64
#  2   driverId         25840 non-null  int64
#  3   constructorId    25840 non-null  int64
#  4   number           25840 non-null  object
#  5   grid             25840 non-null  int64
#  6   position         25840 non-null  object
#  7   positionText     25840 non-null  object
#  8   positionOrder    25840 non-null  int64
#  9   points           25840 non-null  float64
#  10  laps             25840 non-null  int64
#  11  time             25840 non-null  object
#  12  milliseconds     25840 non-null  object
#  13  fastestLap       25840 non-null  object
#  14  rank             25840 non-null  object
#  15  fastestLapTime   25840 non-null  object
#  16  fastestLapSpeed  25840 non-null  object
# ...

# %%
results_df.head()
# Out:
#    resultId  raceId  driverId  constructorId number  grid position
# 0         1      18         1              1     22     1        1  \
# 1         2      18         2              2      3     5        2
# 2         3      18         3              3      7     7        3
# 3         4      18         4              4      5    11        4
# 4         5      18         5              1     23     3        5
#
#   positionText  positionOrder  points  laps         time milliseconds
# 0            1              1    10.0    58  1:34:50.616      5690616  \
# 1            2              2     8.0    58       +5.478      5696094
# 2            3              3     6.0    58       +8.163      5698779
# 3            4              4     5.0    58      +17.181      5707797
# 4            5              5     4.0    58      +18.014      5708630
#
#   fastestLap rank fastestLapTime fastestLapSpeed  statusId
# 0         39    2       1:27.452         218.300         1
# ...

# %%
# Create a new DataFrame 'results_df' with selected columns from 'merged_df'
results_df = results_df[['raceId', 'driverId', 'grid', 'positionOrder', 'laps', 'time', 'milliseconds']]

# Print 'results_df' to verify
print(results_df)
# Out:
#        raceId  driverId  grid  positionOrder  laps         time milliseconds
# 0          18         1     1              1    58  1:34:50.616      5690616
# 1          18         2     5              2    58       +5.478      5696094
# 2          18         3     7              3    58       +8.163      5698779
# 3          18         4    11              4    58      +17.181      5707797
# 4          18         5     3              5    58      +18.014      5708630
# ...       ...       ...   ...            ...   ...          ...          ...
# 25835    1096       854    12             16    57           \N           \N
# 25836    1096       825    16             17    57           \N           \N
# 25837    1096         1     5             18    55           \N           \N
# 25838    1096       849    20             19    55           \N           \N
# 25839    1096         4    10             20    27           \N           \N
#
# [25840 rows x 7 columns]

# %%
drivers_df = pd.read_csv("data/drivers.csv")

# %%
drivers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 857 entries, 0 to 856
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   driverId     857 non-null    int64
#  1   driverRef    857 non-null    object
#  2   number       857 non-null    object
#  3   code         857 non-null    object
#  4   forename     857 non-null    object
#  5   surname      857 non-null    object
#  6   dob          857 non-null    object
#  7   nationality  857 non-null    object
#  8   url          857 non-null    object
# dtypes: int64(1), object(8)
# memory usage: 60.4+ KB

# %%
drivers_df.head()
# Out:
#    driverId   driverRef number code  forename     surname         dob
# 0         1    hamilton     44  HAM     Lewis    Hamilton  1985-01-07  \
# 1         2    heidfeld     \N  HEI      Nick    Heidfeld  1977-05-10
# 2         3     rosberg      6  ROS      Nico     Rosberg  1985-06-27
# 3         4      alonso     14  ALO  Fernando      Alonso  1981-07-29
# 4         5  kovalainen     \N  KOV    Heikki  Kovalainen  1981-10-19
#
#   nationality                                             url
# 0     British     http://en.wikipedia.org/wiki/Lewis_Hamilton
# 1      German      http://en.wikipedia.org/wiki/Nick_Heidfeld
# 2      German       http://en.wikipedia.org/wiki/Nico_Rosberg
# 3     Spanish    http://en.wikipedia.org/wiki/Fernando_Alonso
# 4     Finnish  http://en.wikipedia.org/wiki/Heikki_Kovalainen

# %%
pit_stops_df = pd.read_csv("data/pit_stops.csv")

# %%
pit_stops_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9634 entries, 0 to 9633
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   raceId        9634 non-null   int64
#  1   driverId      9634 non-null   int64
#  2   stop          9634 non-null   int64
#  3   lap           9634 non-null   int64
#  4   time          9634 non-null   object
#  5   duration      9634 non-null   object
#  6   milliseconds  9634 non-null   int64
# dtypes: int64(5), object(2)
# memory usage: 527.0+ KB

# %%
pit_stops_df.head()
# Out:
#    raceId  driverId  stop  lap      time duration  milliseconds
# 0     841       153     1    1  17:05:23   26.898         26898
# 1     841        30     1    1  17:05:52   25.021         25021
# 2     841        17     1   11  17:20:48   23.426         23426
# 3     841         4     1   12  17:22:34   23.251         23251
# 4     841        13     1   13  17:24:10   23.842         23842

# %% [markdown]
# Merging the 6 dataframes

# %%
# Merge the first two dataframes
merged_df = pd.merge(tyre_data, races_with_dummies_df, on=['year'], how='inner')

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 269946 entries, 0 to 269945
# Data columns (total 35 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Driver            269835 non-null  object
#  1   GP                269946 non-null  object
#  2   Tyres             269946 non-null  object
#  3   From              269946 non-null  int64
#  4   To                269946 non-null  int64
#  5   #Laps             269946 non-null  int64
#  6   year              269946 non-null  int64
#  7   location          231048 non-null  object
#  8   raceId_x          269946 non-null  int64
#  9   driverId          266840 non-null  float64
#  10  driverRef         269835 non-null  object
#  11  raceId_y          269946 non-null  int64
#  12  round             269946 non-null  int64
#  13  circuitId         269946 non-null  int64
#  14  name              269946 non-null  object
#  15  date              269946 non-null  object
# ...

# %%
# Merge the next dataframe
merged_df = pd.merge(merged_df, circuits_df, on='circuitId', how='inner')

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 269946 entries, 0 to 269945
# Data columns (total 43 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Driver            269835 non-null  object
#  1   GP                269946 non-null  object
#  2   Tyres             269946 non-null  object
#  3   From              269946 non-null  int64
#  4   To                269946 non-null  int64
#  5   #Laps             269946 non-null  int64
#  6   year              269946 non-null  int64
#  7   location_x        231048 non-null  object
#  8   raceId_x          269946 non-null  int64
#  9   driverId          266840 non-null  float64
#  10  driverRef         269835 non-null  object
#  11  raceId_y          269946 non-null  int64
#  12  round             269946 non-null  int64
#  13  circuitId         269946 non-null  int64
#  14  name_x            269946 non-null  object
#  15  date              269946 non-null  object
# ...

# %%
# Merge the drivers_df dataframe
merged_df = pd.merge(merged_df, drivers_df, on=['driverId','driverRef'], how='inner')

# %%
merged_df.head()
# Out:
#           Driver         GP         Tyres  From  To  #Laps  year
# 0  Jenson Button  Australia          Soft     1  16     16  2012  \
# 1  Jenson Button  Australia        Medium    17  36     20  2012
# 2  Jenson Button  Australia        Medium    37  58     22  2012
# 3  Jenson Button   Malaysia  Intermediate     1   4      4  2012
# 4  Jenson Button   Malaysia           Wet     5  13      9  2012
#
#      location_x  raceId_x  driverId  ...      lng  alt
# 0      Adelaide       860      18.0  ...  144.968   10  \
# 1      Adelaide       860      18.0  ...  144.968   10
# 2      Adelaide       860      18.0  ...  144.968   10
# 3  Kuala Lumpur       861      18.0  ...  144.968   10
# 4  Kuala Lumpur       861      18.0  ...  144.968   10
#
#                                                url_y  number code forename
# 0  http://en.wikipedia.org/wiki/Melbourne_Grand_P...      22  BUT   Jenson  \
# 1  http://en.wikipedia.org/wiki/Melbourne_Grand_P...      22  BUT   Jenson
# ...

# %%
merged_df.columns
# Out:
# Index(['Driver', 'GP', 'Tyres', 'From', 'To', '#Laps', 'year', 'location_x',
#        'raceId_x', 'driverId', 'driverRef', 'raceId_y', 'round', 'circuitId',
#        'name_x', 'date', 'time', 'url_x', 'fp1_date', 'fp1_time', 'fp2_date',
#        'fp2_time', 'fp3_date', 'fp3_time', 'quali_date', 'quali_time',
#        'sprint_date', 'sprint_time', 'weather_category', 'weather_cloudy',
#        'weather_cold', 'weather_dry', 'weather_unknown', 'weather_warm',
#        'weather_wet', 'circuitRef', 'name_y', 'location_y', 'country', 'lat',
#        'lng', 'alt', 'url_y', 'number', 'code', 'forename', 'surname', 'dob',
#        'nationality', 'url'],
#       dtype='object')

# %%
# List of columns to drop
columns_to_drop = ['fp1_date', 'fp1_time', 'fp2_date','fp2_time','fp3_date','fp3_time','quali_date','quali_time','sprint_date','sprint_time','lat','lng','url']

# Drop the specified columns
merged_df.drop(columns_to_drop, axis=1, inplace=True)

# Print the updated DataFrame
print(merged_df)
# Out:
#                 Driver            GP         Tyres  From  To  #Laps  year
# 0        Jenson Button     Australia          Soft     1  16     16  2012  \
# 1        Jenson Button     Australia        Medium    17  36     20  2012
# 2        Jenson Button     Australia        Medium    37  58     22  2012
# 3        Jenson Button      Malaysia  Intermediate     1   4      4  2012
# 4        Jenson Button      Malaysia           Wet     5  13      9  2012
# ...                ...           ...           ...   ...  ..    ...   ...
# 253843  Nikita Mazepin        Brazil          Hard    35  69     35  2021
# 253844  Nikita Mazepin         Qatar        Medium     1  31     31  2021
# 253845  Nikita Mazepin         Qatar          Soft    32  55     24  2021
# 253846  Nikita Mazepin  Saudi Arabia        Medium     1  13     13  2021
# 253847  Nikita Mazepin  Saudi Arabia          Hard    14  14      1  2021
#
#             location_x  raceId_x  driverId  ... location_y       country  alt
# ...

# %%
merged_df.columns
# Out:
# Index(['Driver', 'GP', 'Tyres', 'From', 'To', '#Laps', 'year', 'location_x',
#        'raceId_x', 'driverId', 'driverRef', 'raceId_y', 'round', 'circuitId',
#        'name_x', 'date', 'time', 'url_x', 'weather_category', 'weather_cloudy',
#        'weather_cold', 'weather_dry', 'weather_unknown', 'weather_warm',
#        'weather_wet', 'circuitRef', 'name_y', 'location_y', 'country', 'alt',
#        'url_y', 'number', 'code', 'forename', 'surname', 'dob', 'nationality'],
#       dtype='object')

# %%
merged_df.head()
# Out:
#           Driver         GP         Tyres  From  To  #Laps  year
# 0  Jenson Button  Australia          Soft     1  16     16  2012  \
# 1  Jenson Button  Australia        Medium    17  36     20  2012
# 2  Jenson Button  Australia        Medium    37  58     22  2012
# 3  Jenson Button   Malaysia  Intermediate     1   4      4  2012
# 4  Jenson Button   Malaysia           Wet     5  13      9  2012
#
#      location_x  raceId_x  driverId  ... location_y    country  alt
# 0      Adelaide       860      18.0  ...  Melbourne  Australia   10  \
# 1      Adelaide       860      18.0  ...  Melbourne  Australia   10
# 2      Adelaide       860      18.0  ...  Melbourne  Australia   10
# 3  Kuala Lumpur       861      18.0  ...  Melbourne  Australia   10
# 4  Kuala Lumpur       861      18.0  ...  Melbourne  Australia   10
#
#                                                url_y number code forename
# 0  http://en.wikipedia.org/wiki/Melbourne_Grand_P...     22  BUT   Jenson  \
# ...

# %%
# Print only the 'raceId_x' and 'raceId_y' columns from 'merged_df'
print(merged_df[['raceId_x', 'raceId_y']])
# Out:
#         raceId_x  raceId_y
# 0            860       860
# 1            860       860
# 2            860       860
# 3            861       860
# 4            861       860
# ...          ...       ...
# 253843      1071      1072
# 253844      1051      1072
# 253845      1051      1072
# 253846      1072      1072
# 253847      1072      1072
#
# [253848 rows x 2 columns]

# %%
# Merge the results_df dataframe
merged_df = pd.merge(merged_df, results_df, on=['driverId','raceId'], how='inner')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/g4/vm6jsw_s0hlcmn6jslrlcxm80000gp/T/ipykernel_68214/414993099.py in ?()
#       1 # Merge the results_df dataframe
# ----> 2 merged_df = pd.merge(merged_df, results_df, on=['driverId','raceId'], how='inner')
#
# ~/neuefische/Formula-1-Project/.venv/lib/python3.11/site-packages/pandas/core/reshape/merge.py in ?(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     140     copy: bool | None = None,
#     141     indicator: str | bool = False,
#     142     validate: str | None = None,
#     143 ) -> DataFrame:
# --> 144     op = _MergeOperation(
#     145         left,
#     146         right,
#     147         how=how,
#
# ...

# %%
# Merge the results_df dataframe
#merged_df = pd.merge(merged_df, results_df, on=['raceId', 'driverId'], how='inner')

# %%
merged_df.head(40)
# Out:
#            Driver         GP Tyres  From  To  #Laps  year location_x
# 0   Jenson Button  Australia  Soft     1  16     16  2012   Adelaide  \
# 1   Jenson Button  Australia  Soft     1  16     16  2012   Adelaide
# 2   Jenson Button  Australia  Soft     1  16     16  2012   Adelaide
# 3   Jenson Button  Australia  Soft     1  16     16  2012   Adelaide
# 4   Jenson Button  Australia  Soft     1  16     16  2012   Adelaide
# 5   Jenson Button  Australia  Soft     1  16     16  2012   Adelaide
# 6   Jenson Button  Australia  Soft     1  16     16  2012   Adelaide
# 7   Jenson Button  Australia  Soft     1  16     16  2012   Adelaide
# 8   Jenson Button  Australia  Soft     1  16     16  2012   Adelaide
# 9   Jenson Button  Australia  Soft     1  16     16  2012   Adelaide
# 10  Jenson Button  Australia  Soft     1  16     16  2012   Adelaide
# 11  Jenson Button  Australia  Soft     1  16     16  2012   Adelaide
# 12  Jenson Button  Australia  Soft     1  16     16  2012   Adelaide
# ...

# %%
# Merge the results_df dataframe
merged_df = pd.merge(merged_df, results_df, on=['raceId', 'driverId'], how='inner')

# Merge the drivers_df dataframe
merged_df = pd.merge(merged_df, drivers_df, on='driverId', how='inner')

# Merge the pit_stops_df dataframe
merged_df = pd.merge(merged_df, pit_stops_df, on=['raceId', 'driverId'], how='inner')

# Now you have merged all your dataframes into one comprehensive dataframe (merged_df)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[72], line 2
#       1 # Merge the results_df dataframe
# ----> 2 merged_df = pd.merge(merged_df, results_df, on=['raceId', 'driverId'], how='inner')
#       4 # Merge the drivers_df dataframe
#       5 merged_df = pd.merge(merged_df, drivers_df, on='driverId', how='inner')
#
# File ~/neuefische/Formula-1-Project/.venv/lib/python3.11/site-packages/pandas/core/reshape/merge.py:158, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     127 @Substitution("\nleft : DataFrame or named Series")
#     128 @Appender(_merge_doc, indents=0)
#     129 def merge(
#    (...)
#     142     validate: str | None = None,
#     143 ) -> DataFrame:
#     144     op = _MergeOperation(
#     145         left,
#     146         right,
#    (...)
# ...

# %%
print("Column names in tyre_data_cleaned:")
print(tyre_data_cleaned.columns)

print("\nColumn names in races_with_dummies_df:")
print(races_with_dummies_df.columns)
# Out:
# Column names in tyre_data_cleaned:
# Index(['driver', 'gp', 'tyres', 'from', 'to', '#laps', 'year'], dtype='object')
#
# Column names in races_with_dummies_df:
# Index(['raceId', 'year', 'round', 'circuitId', 'name', 'date', 'time', 'url',
#        'fp1_date', 'fp1_time', 'fp2_date', 'fp2_time', 'fp3_date', 'fp3_time',
#        'quali_date', 'quali_time', 'sprint_date', 'sprint_time',
#        'weather_category', 'weather_cloudy', 'weather_cold', 'weather_dry',
#        'weather_unknown', 'weather_warm', 'weather_wet'],
#       dtype='object')

# %%
print("Data types in tyre_data_cleaned:")
print(tyre_data_cleaned.dtypes)

print("\nData types in races_with_dummies_df:")
print(races_with_dummies_df.dtypes)
# Out:
# Data types in tyre_data_cleaned:
# driver    object
# gp        object
# tyres     object
# from       int64
# to         int64
# #laps      int64
# year       int64
# dtype: object
#
# Data types in races_with_dummies_df:
# raceId               int64
# year                 int64
# round                int64
# circuitId            int64
# name                object
# date                object
# time                object
# url                 object
# fp1_date            object
# fp1_time            object
# fp2_date            object
# fp2_time            object
# fp3_date            object
# fp3_time            object
# quali_date          object
# quali_time          object
# sprint_date         object
# sprint_time         object
# weather_category    object
# weather_cloudy        bool
# weather_cold          bool
# weather_dry           bool
# weather_unknown       bool
# weather_warm          bool
# weather_wet           bool
# dtype: object

# %%
print("Duplicate column names in tyre_data_cleaned:")
print(tyre_data_cleaned.columns[tyre_data_cleaned.columns.duplicated()])

print("\nDuplicate column names in races_with_dummies_df:")
print(races_with_dummies_df.columns[races_with_dummies_df.columns.duplicated()])
# Out:
# Duplicate column names in tyre_data_cleaned:
# Index([], dtype='object')
#
# Duplicate column names in races_with_dummies_df:
# Index([], dtype='object')

# %%
# Merge with just the 'year' column from tyre_data_cleaned and 'year' column from races_with_dummies_df
merged_df = pd.merge(tyre_data_cleaned[['year']], races_with_dummies_df[['year']], on='year', how='inner')

# %%
# Merge with just the 'year' column from tyre_data_cleaned and 'year' column from races_with_dummies_df
merged_df = pd.merge(tyre_data_cleaned[['year']], races_with_dummies_df[['year']], on='year', how='inner')

# %%
# Merge with 'year' and 'gp' columns
merged_df = pd.merge(merged_df, tyre_data_cleaned[['year', 'gp']], on=['year', 'gp'], how='inner')

# Continue adding columns one by one
# merged_df = pd.merge(merged_df, other_dataframe[['column_name']], on='column_name', how='inner')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/g4/vm6jsw_s0hlcmn6jslrlcxm80000gp/T/ipykernel_63996/4098365512.py in ?()
#       1 # Merge with 'year' and 'gp' columns
# ----> 2 merged_df = pd.merge(merged_df, tyre_data_cleaned[['year', 'gp']], on=['year', 'gp'], how='inner')
#       3
#       4 # Continue adding columns one by one
#       5 # merged_df = pd.merge(merged_df, other_dataframe[['column_name']], on='column_name', how='inner')
#
# ~/neuefische/Formula-1-Project/.venv/lib/python3.11/site-packages/pandas/core/reshape/merge.py in ?(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     140     copy: bool | None = None,
#     141     indicator: str | bool = False,
#     142     validate: str | None = None,
#     143 ) -> DataFrame:
# --> 144     op = _MergeOperation(
#     145         left,
# ...
