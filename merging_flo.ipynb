# %%
# importing
import pandas as pd

# %%
# read in data csv/frames

circuits_df = pd.read_csv("data/circuits.csv")
constructor_results_df = pd.read_csv("data/constructor_results.csv")
constructors_df = pd.read_csv("data/constructors.csv")
driver_standings_df = pd.read_csv("data/driver_standings.csv")
drivers_df = pd.read_csv("data/drivers.csv")
lap_times_df = pd.read_csv("data/lap_times.csv")
pit_stops_df = pd.read_csv("data/pit_stops.csv")
qualifying_df = pd.read_csv("data/qualifying.csv")
races_df = pd.read_csv("data/races.csv")
results_df = pd.read_csv("data/results.csv")
seasons_df = pd.read_csv("data/seasons.csv")
sprint_res_df = pd.read_csv("data/sprint_results.csv")
status_df = pd.read_csv("data/status.csv")
tyre_data_df = pd.read_csv("data/tyre_data.csv")
races_with_weather_df = pd.read_csv("data/races_with_weather.csv")
races_with_dummies_df = pd.read_csv("data/races_with_dummies.csv")
tyre_data_new_df = pd.read_csv("data/tyre_data_new.csv")

# %% [markdown]
# Merging the different data frames to get one data frame for the machine learning model.
#
# - make a list to find the most interesting/important ones
# - merge
#
# - only extract data from 2012-2022 -> we got tyre data for this time frame
# - Drop unnecessary columns, duplicates and one of the dummies if created (weather data)
# 4.

# %% [markdown]
# List of dfs needed:
#
# 1. tyre_data_new_df x
# 2. circuits_df x
# 3. drivers_df x
# 4. lap_times_df
# 5. pit_stops_df x
# 6. races_with_dummies (included weather data in dummie variables) x
# 7. results_df x
#
# Optional:
#
# 1. constructor_results_df
# 2. constructors_df
# 3. status_df

# %%
# merging 

part_1 = pd.merge(tyre_data_new_df, races_with_dummies_df, on="raceId")

# %%
part_2 = pd.merge(part_1, circuits_df, on="circuitId")

# %%
part_2.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0            Driver         GP       Tyres  From
# 0             0           0     Jenson Button  Australia   Soft Used     1  \
# 1             1           1     Jenson Button  Australia  Medium New    17
# 2             2           2     Jenson Button  Australia  Medium New    37
# 3             3           3  Sebastian Vettel  Australia   Soft Used     1
# 4             4           4  Sebastian Vettel  Australia   Soft Used    17
#
#    To  #Laps  year_x location_x  raceId  year_y  round  circuitId
# 0  16     16    2012   Adelaide     860    2012      1          1  \
# 1  36     20    2012   Adelaide     860    2012      1          1
# 2  58     22    2012   Adelaide     860    2012      1          1
# 3  16     16    2012   Adelaide     860    2012      1          1
# 4  37     21    2012   Adelaide     860    2012      1          1
#
#                   name_x        date      time
# 0  Australian Grand Prix  2012-03-18  06:00:00  \
# 1  Australian Grand Prix  2012-03-18  06:00:00
# 2  Australian Grand Prix  2012-03-18  06:00:00
# 3  Australian Grand Prix  2012-03-18  06:00:00
# 4  Australian Grand Prix  2012-03-18  06:00:00
#
#                                                url_x fp1_date fp1_time
# 0  http://en.wikipedia.org/wiki/2012_Australian_G...       \N       \N  \
# 1  http://en.wikipedia.org/wiki/2012_Australian_G...       \N       \N
# 2  http://en.wikipedia.org/wiki/2012_Australian_G...       \N       \N
# 3  http://en.wikipedia.org/wiki/2012_Australian_G...       \N       \N
# 4  http://en.wikipedia.org/wiki/2012_Australian_G...       \N       \N
#
#   fp2_date fp2_time fp3_date fp3_time quali_date quali_time sprint_date
# 0       \N       \N       \N       \N         \N         \N          \N  \
# 1       \N       \N       \N       \N         \N         \N          \N
# 2       \N       \N       \N       \N         \N         \N          \N
# 3       \N       \N       \N       \N         \N         \N          \N
# 4       \N       \N       \N       \N         \N         \N          \N
#
#   sprint_time weather_category  weather_cloudy  weather_cold  weather_dry
# 0          \N     weather_warm           False         False        False  \
# 1          \N     weather_warm           False         False        False
# 2          \N     weather_warm           False         False        False
# 3          \N     weather_warm           False         False        False
# 4          \N     weather_warm           False         False        False
#
#    weather_unknown  weather_warm  weather_wet   circuitRef
# 0            False          True        False  albert_park  \
# 1            False          True        False  albert_park
# 2            False          True        False  albert_park
# 3            False          True        False  albert_park
# 4            False          True        False  albert_park
#
#                            name_y location_y    country      lat      lng alt
# 0  Albert Park Grand Prix Circuit  Melbourne  Australia -37.8497  144.968  10  \
# 1  Albert Park Grand Prix Circuit  Melbourne  Australia -37.8497  144.968  10
# 2  Albert Park Grand Prix Circuit  Melbourne  Australia -37.8497  144.968  10
# 3  Albert Park Grand Prix Circuit  Melbourne  Australia -37.8497  144.968  10
# 4  Albert Park Grand Prix Circuit  Melbourne  Australia -37.8497  144.968  10
#
#                                                url_y
# 0  http://en.wikipedia.org/wiki/Melbourne_Grand_P...
# 1  http://en.wikipedia.org/wiki/Melbourne_Grand_P...
# 2  http://en.wikipedia.org/wiki/Melbourne_Grand_P...
# 3  http://en.wikipedia.org/wiki/Melbourne_Grand_P...
# 4  http://en.wikipedia.org/wiki/Melbourne_Grand_P...

# %%
part_3 = pd.merge(part_2, results_df, on="raceId")

# %%
part_3.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0         Driver         GP      Tyres  From  To
# 0             0           0  Jenson Button  Australia  Soft Used     1  16  \
# 1             0           0  Jenson Button  Australia  Soft Used     1  16
# 2             0           0  Jenson Button  Australia  Soft Used     1  16
# 3             0           0  Jenson Button  Australia  Soft Used     1  16
# 4             0           0  Jenson Button  Australia  Soft Used     1  16
#
#    #Laps  year_x location_x  raceId  year_y  round  circuitId
# 0     16    2012   Adelaide     860    2012      1          1  \
# 1     16    2012   Adelaide     860    2012      1          1
# 2     16    2012   Adelaide     860    2012      1          1
# 3     16    2012   Adelaide     860    2012      1          1
# 4     16    2012   Adelaide     860    2012      1          1
#
#                   name_x        date    time_x
# 0  Australian Grand Prix  2012-03-18  06:00:00  \
# 1  Australian Grand Prix  2012-03-18  06:00:00
# 2  Australian Grand Prix  2012-03-18  06:00:00
# 3  Australian Grand Prix  2012-03-18  06:00:00
# 4  Australian Grand Prix  2012-03-18  06:00:00
#
#                                                url_x fp1_date fp1_time
# 0  http://en.wikipedia.org/wiki/2012_Australian_G...       \N       \N  \
# 1  http://en.wikipedia.org/wiki/2012_Australian_G...       \N       \N
# 2  http://en.wikipedia.org/wiki/2012_Australian_G...       \N       \N
# 3  http://en.wikipedia.org/wiki/2012_Australian_G...       \N       \N
# 4  http://en.wikipedia.org/wiki/2012_Australian_G...       \N       \N
#
#   fp2_date fp2_time fp3_date fp3_time quali_date quali_time sprint_date
# 0       \N       \N       \N       \N         \N         \N          \N  \
# 1       \N       \N       \N       \N         \N         \N          \N
# 2       \N       \N       \N       \N         \N         \N          \N
# 3       \N       \N       \N       \N         \N         \N          \N
# 4       \N       \N       \N       \N         \N         \N          \N
#
#   sprint_time weather_category  weather_cloudy  weather_cold  weather_dry
# 0          \N     weather_warm           False         False        False  \
# 1          \N     weather_warm           False         False        False
# 2          \N     weather_warm           False         False        False
# 3          \N     weather_warm           False         False        False
# 4          \N     weather_warm           False         False        False
#
#    weather_unknown  weather_warm  weather_wet   circuitRef
# 0            False          True        False  albert_park  \
# 1            False          True        False  albert_park
# 2            False          True        False  albert_park
# 3            False          True        False  albert_park
# 4            False          True        False  albert_park
#
#                            name_y location_y    country      lat      lng alt
# 0  Albert Park Grand Prix Circuit  Melbourne  Australia -37.8497  144.968  10  \
# 1  Albert Park Grand Prix Circuit  Melbourne  Australia -37.8497  144.968  10
# 2  Albert Park Grand Prix Circuit  Melbourne  Australia -37.8497  144.968  10
# 3  Albert Park Grand Prix Circuit  Melbourne  Australia -37.8497  144.968  10
# 4  Albert Park Grand Prix Circuit  Melbourne  Australia -37.8497  144.968  10
#
#                                                url_y  resultId  driverId
# 0  http://en.wikipedia.org/wiki/Melbourne_Grand_P...     21232        18  \
# 1  http://en.wikipedia.org/wiki/Melbourne_Grand_P...     21233        20
# 2  http://en.wikipedia.org/wiki/Melbourne_Grand_P...     21234         1
# 3  http://en.wikipedia.org/wiki/Melbourne_Grand_P...     21235        17
# 4  http://en.wikipedia.org/wiki/Melbourne_Grand_P...     21236         4
#
#    constructorId number  grid position positionText  positionOrder  points
# 0              1      3     2        1            1              1    25.0  \
# 1              9      1     6        2            2              2    18.0
# 2              1      4     1        3            3              3    15.0
# 3              9      2     5        4            4              4    12.0
# 4              6      5    12        5            5              5    10.0
#
#    laps       time_y milliseconds fastestLap rank fastestLapTime
# 0    58  1:34:09.565      5649565         56    1       1:29.187  \
# 1    58       +2.139      5651704         57    2       1:29.417
# 2    58       +4.075      5653640         57    4       1:29.538
# 3    58       +4.547      5654112         57    3       1:29.438
# 4    58      +21.565      5671130         52    7       1:30.277
#
#   fastestLapSpeed  statusId
# 0         214.053         1
# 1         213.503         1
# 2         213.214         1
# 3         213.452         1
# 4         211.469         1

# %%
part_4 = pd.merge(part_3, drivers_df, on="driverId")

# %%
part_5 = pd.merge(part_4, pit_stops_df, on="raceId")

# %%
pd.set_option('display.max_columns', None)
part_5.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0         Driver         GP      Tyres  From  To
# 0             0           0  Jenson Button  Australia  Soft Used     1  16  \
# 1             0           0  Jenson Button  Australia  Soft Used     1  16
# 2             0           0  Jenson Button  Australia  Soft Used     1  16
# 3             0           0  Jenson Button  Australia  Soft Used     1  16
# 4             0           0  Jenson Button  Australia  Soft Used     1  16
#
#    #Laps  year_x location_x  raceId  year_y  round  circuitId
# 0     16    2012   Adelaide     860    2012      1          1  \
# 1     16    2012   Adelaide     860    2012      1          1
# 2     16    2012   Adelaide     860    2012      1          1
# 3     16    2012   Adelaide     860    2012      1          1
# 4     16    2012   Adelaide     860    2012      1          1
#
#                   name_x        date    time_x
# 0  Australian Grand Prix  2012-03-18  06:00:00  \
# 1  Australian Grand Prix  2012-03-18  06:00:00
# 2  Australian Grand Prix  2012-03-18  06:00:00
# 3  Australian Grand Prix  2012-03-18  06:00:00
# 4  Australian Grand Prix  2012-03-18  06:00:00
#
#                                                url_x fp1_date fp1_time
# 0  http://en.wikipedia.org/wiki/2012_Australian_G...       \N       \N  \
# 1  http://en.wikipedia.org/wiki/2012_Australian_G...       \N       \N
# 2  http://en.wikipedia.org/wiki/2012_Australian_G...       \N       \N
# 3  http://en.wikipedia.org/wiki/2012_Australian_G...       \N       \N
# 4  http://en.wikipedia.org/wiki/2012_Australian_G...       \N       \N
#
#   fp2_date fp2_time fp3_date fp3_time quali_date quali_time sprint_date
# 0       \N       \N       \N       \N         \N         \N          \N  \
# 1       \N       \N       \N       \N         \N         \N          \N
# 2       \N       \N       \N       \N         \N         \N          \N
# 3       \N       \N       \N       \N         \N         \N          \N
# 4       \N       \N       \N       \N         \N         \N          \N
#
#   sprint_time weather_category  weather_cloudy  weather_cold  weather_dry
# 0          \N     weather_warm           False         False        False  \
# 1          \N     weather_warm           False         False        False
# 2          \N     weather_warm           False         False        False
# 3          \N     weather_warm           False         False        False
# 4          \N     weather_warm           False         False        False
#
#    weather_unknown  weather_warm  weather_wet   circuitRef
# 0            False          True        False  albert_park  \
# 1            False          True        False  albert_park
# 2            False          True        False  albert_park
# 3            False          True        False  albert_park
# 4            False          True        False  albert_park
#
#                            name_y location_y    country      lat      lng alt
# 0  Albert Park Grand Prix Circuit  Melbourne  Australia -37.8497  144.968  10  \
# 1  Albert Park Grand Prix Circuit  Melbourne  Australia -37.8497  144.968  10
# 2  Albert Park Grand Prix Circuit  Melbourne  Australia -37.8497  144.968  10
# 3  Albert Park Grand Prix Circuit  Melbourne  Australia -37.8497  144.968  10
# 4  Albert Park Grand Prix Circuit  Melbourne  Australia -37.8497  144.968  10
#
#                                                url_y  resultId  driverId_x
# 0  http://en.wikipedia.org/wiki/Melbourne_Grand_P...     21232          18  \
# 1  http://en.wikipedia.org/wiki/Melbourne_Grand_P...     21232          18
# 2  http://en.wikipedia.org/wiki/Melbourne_Grand_P...     21232          18
# 3  http://en.wikipedia.org/wiki/Melbourne_Grand_P...     21232          18
# 4  http://en.wikipedia.org/wiki/Melbourne_Grand_P...     21232          18
#
#    constructorId number_x  grid position positionText  positionOrder  points
# 0              1        3     2        1            1              1    25.0  \
# 1              1        3     2        1            1              1    25.0
# 2              1        3     2        1            1              1    25.0
# 3              1        3     2        1            1              1    25.0
# 4              1        3     2        1            1              1    25.0
#
#    laps       time_y milliseconds_x fastestLap rank fastestLapTime
# 0    58  1:34:09.565        5649565         56    1       1:29.187  \
# 1    58  1:34:09.565        5649565         56    1       1:29.187
# 2    58  1:34:09.565        5649565         56    1       1:29.187
# 3    58  1:34:09.565        5649565         56    1       1:29.187
# 4    58  1:34:09.565        5649565         56    1       1:29.187
#
#   fastestLapSpeed  statusId driverRef number_y code forename surname
# 0         214.053         1    button       22  BUT   Jenson  Button  \
# 1         214.053         1    button       22  BUT   Jenson  Button
# 2         214.053         1    button       22  BUT   Jenson  Button
# 3         214.053         1    button       22  BUT   Jenson  Button
# 4         214.053         1    button       22  BUT   Jenson  Button
#
#           dob nationality                                         url
# 0  1980-01-19     British  http://en.wikipedia.org/wiki/Jenson_Button  \
# 1  1980-01-19     British  http://en.wikipedia.org/wiki/Jenson_Button
# 2  1980-01-19     British  http://en.wikipedia.org/wiki/Jenson_Button
# 3  1980-01-19     British  http://en.wikipedia.org/wiki/Jenson_Button
# 4  1980-01-19     British  http://en.wikipedia.org/wiki/Jenson_Button
#
#    driverId_y  stop  lap      time duration  milliseconds_y
# 0         811     1    1  17:05:23   24.599           24599
# 1         817     1    1  17:05:35   32.319           32319
# 2          13     1   11  17:21:08   22.313           22313
# 3           3     1   12  17:22:31   23.203           23203
# 4           4     1   13  17:24:04   22.035           22035

# %%
part_5.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'Driver', 'GP', 'Tyres', 'From', 'To',
#        '#Laps', 'year_x', 'location_x', 'raceId', 'year_y', 'round',
#        'circuitId', 'name_x', 'date', 'time_x', 'url_x', 'fp1_date',
#        'fp1_time', 'fp2_date', 'fp2_time', 'fp3_date', 'fp3_time',
#        'quali_date', 'quali_time', 'sprint_date', 'sprint_time',
#        'weather_category', 'weather_cloudy', 'weather_cold', 'weather_dry',
#        'weather_unknown', 'weather_warm', 'weather_wet', 'circuitRef',
#        'name_y', 'location_y', 'country', 'lat', 'lng', 'alt', 'url_y',
#        'resultId', 'driverId_x', 'constructorId', 'number_x', 'grid',
#        'position', 'positionText', 'positionOrder', 'points', 'laps', 'time_y',
#        'milliseconds_x', 'fastestLap', 'rank', 'fastestLapTime',
#        'fastestLapSpeed', 'statusId', 'driverRef', 'number_y', 'code',
#        'forename', 'surname', 'dob', 'nationality', 'url', 'driverId_y',
#        'stop', 'lap', 'time', 'duration', 'milliseconds_y'],
#       dtype='object')

# %% [markdown]
# Drop duplicates and unnecessary columns

# %%
columns_to_drop = ['Unnamed: 0.1','Unnamed: 0','fp1_date',
       'fp1_time', 'fp2_date', 'fp2_time', 'fp3_date', 'fp3_time',
       'quali_date', 'quali_time', 'sprint_date', 'sprint_time', "name_y","url_x", "url_y","year_y","location_x","driverId_y","Driver","code","forename","url","nationality","number_y","positionText","GP","location_y","country","lat","lng","alt","circuitRef","driverRef","dob","weather_category","weather_unknown" ]

part_5_tiny_df = part_5.drop(columns=columns_to_drop)

# %% [markdown]
# time_x -> starting time
# time_y -> race duration

# %%
part_5_tiny_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11107982 entries, 0 to 11107981
# Data columns (total 38 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   Tyres            object
#  1   From             int64
#  2   To               int64
#  3   #Laps            int64
#  4   year_x           int64
#  5   raceId           int64
#  6   round            int64
#  7   circuitId        int64
#  8   name_x           object
#  9   date             object
#  10  time_x           object
#  11  weather_cloudy   bool
#  12  weather_cold     bool
#  13  weather_dry      bool
#  14  weather_warm     bool
#  15  weather_wet      bool
#  16  resultId         int64
#  17  driverId_x       int64
#  18  constructorId    int64
#  19  number_x         object
#  20  grid             int64
#  21  position         object
#  22  positionOrder    int64
#  23  points           float64
#  24  laps             int64
#  25  time_y           object
#  26  milliseconds_x   object
#  27  fastestLap       object
#  28  rank             object
#  29  fastestLapTime   object
#  30  fastestLapSpeed  object
#  31  statusId         int64
#  32  surname          object
#  33  stop             int64
#  34  lap              int64
#  35  time             object
#  36  duration         object
#  37  milliseconds_y   int64
# dtypes: bool(5), float64(1), int64(17), object(15)
# memory usage: 2.8+ GB

# %%
part_5_tiny_df.columns
# Out:
# Index(['Tyres', 'From', 'To', '#Laps', 'year_x', 'raceId', 'round',
#        'circuitId', 'name_x', 'date', 'time_x', 'weather_cloudy',
#        'weather_cold', 'weather_dry', 'weather_warm', 'weather_wet',
#        'resultId', 'driverId_x', 'constructorId', 'number_x', 'grid',
#        'position', 'positionOrder', 'points', 'laps', 'time_y',
#        'milliseconds_x', 'fastestLap', 'rank', 'fastestLapTime',
#        'fastestLapSpeed', 'statusId', 'surname', 'stop', 'lap', 'time',
#        'duration', 'milliseconds_y'],
#       dtype='object')

# %%
part_5_tiny_df.Tyres.unique()
# Out:
# array(['Soft Used', 'Medium New', 'Soft New', 'Medium Used',
#        'Supersoft Used', 'Supersoft New', 'Ultrasoft Used',
#        'Ultrasoft New', 'Intermediate New', 'Wet New', 'Hard New',
#        'Intermediate Used', 'Lluvia Extrema Usado', 'Hard Used',
#        'Hiper Blando Usado', 'Hiper Blando Nuevo'], dtype=object)

# %%
part_5_tiny_df["year_x"].unique
# Out:
# <bound method Series.unique of 0           2012
# 1           2012
# 2           2012
# 3           2012
# 4           2012
#             ...
# 11107977    2022
# 11107978    2022
# 11107979    2022
# 11107980    2022
# 11107981    2022
# Name: year_x, Length: 11107982, dtype: int64>

# %%
part_5_tiny_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11107982 entries, 0 to 11107981
# Data columns (total 39 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   Driver           object
#  1   Tyres            object
#  2   From             int64
#  3   To               int64
#  4   #Laps            int64
#  5   year_x           int64
#  6   raceId           int64
#  7   round            int64
#  8   circuitId        int64
#  9   name_x           object
#  10  date             object
#  11  time_x           object
#  12  weather_cloudy   bool
#  13  weather_cold     bool
#  14  weather_dry      bool
#  15  weather_warm     bool
#  16  weather_wet      bool
#  17  resultId         int64
#  18  driverId_x       int64
#  19  constructorId    int64
#  20  number_x         object
#  21  grid             int64
#  22  position         object
#  23  positionOrder    int64
#  24  points           float64
#  25  laps             int64
#  26  time_y           object
#  27  milliseconds_x   object
#  28  fastestLap       object
#  29  rank             object
#  30  fastestLapTime   object
#  31  fastestLapSpeed  object
#  32  statusId         int64
#  33  surname          object
#  34  stop             int64
#  35  lap              int64
#  36  time             object
#  37  duration         object
#  38  milliseconds_y   int64
# dtypes: bool(5), float64(1), int64(17), object(16)
# memory usage: 2.9+ GB

# %%
constructors_df = constructors_df.drop('url', axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 constructors_df = constructors_df.drop('url', axis=1)
#
# File ~/neuefische/Formula-1-Project/.venv/lib/python3.9/site-packages/pandas/core/frame.py:5268, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5120 def drop(
#    5121     self,
#    5122     labels: IndexLabel = None,
#    (...)
#    5129     errors: IgnoreRaise = "raise",
#    5130 ) -> DataFrame | None:
#    5131     """
#    5132     Drop specified labels from rows or columns.
#    5133
#    (...)
#    5266             weight  1.0     0.8
#    5267     """
# -> 5268     return super().drop(
#    5269         labels=labels,
#    5270         axis=axis,
#    5271         index=index,
#    5272         columns=columns,
#    5273         level=level,
#    5274         inplace=inplace,
#    5275         errors=errors,
#    5276     )
#
# File ~/neuefische/Formula-1-Project/.venv/lib/python3.9/site-packages/pandas/core/generic.py:4549, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4547 for axis, labels in axes.items():
#    4548     if labels is not None:
# -> 4549         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4551 if inplace:
#    4552     self._update_inplace(obj)
#
# File ~/neuefische/Formula-1-Project/.venv/lib/python3.9/site-packages/pandas/core/generic.py:4591, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4589         new_axis = axis.drop(labels, level=level, errors=errors)
#    4590     else:
# -> 4591         new_axis = axis.drop(labels, errors=errors)
#    4592     indexer = axis.get_indexer(new_axis)
#    4594 # Case for non-unique axis
#    4595 else:
#
# File ~/neuefische/Formula-1-Project/.venv/lib/python3.9/site-packages/pandas/core/indexes/base.py:6696, in Index.drop(self, labels, errors)
#    6694 if mask.any():
#    6695     if errors != "ignore":
# -> 6696         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6697     indexer = indexer[~mask]
#    6698 return self.delete(indexer)
#
# KeyError: "['url'] not found in axis"

# %%
part_6 = pd.merge(part_5_tiny_df, constructors_df, on="constructorId")

# %%
complete_ml_df = part_6

# %%
complete_ml_df.isna().sum()
# Out:
# Tyres              0
# From               0
# To                 0
# #Laps              0
# year_x             0
# raceId             0
# round              0
# circuitId          0
# name_x             0
# date               0
# time_x             0
# weather_cloudy     0
# weather_cold       0
# weather_dry        0
# weather_warm       0
# weather_wet        0
# resultId           0
# driverId_x         0
# constructorId      0
# number_x           0
# grid               0
# position           0
# positionOrder      0
# points             0
# laps               0
# time_y             0
# milliseconds_x     0
# fastestLap         0
# rank               0
# fastestLapTime     0
# fastestLapSpeed    0
# statusId           0
# surname            0
# stop               0
# lap                0
# time               0
# duration           0
# milliseconds_y     0
# constructorRef     0
# name               0
# nationality        0
# dtype: int64

# %%
complete_ml_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11107982 entries, 0 to 11107981
# Data columns (total 42 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   Driver           object
#  1   Tyres            object
#  2   From             int64
#  3   To               int64
#  4   #Laps            int64
#  5   year_x           int64
#  6   raceId           int64
#  7   round            int64
#  8   circuitId        int64
#  9   name_x           object
#  10  date             object
#  11  time_x           object
#  12  weather_cloudy   bool
#  13  weather_cold     bool
#  14  weather_dry      bool
#  15  weather_warm     bool
#  16  weather_wet      bool
#  17  resultId         int64
#  18  driverId_x       int64
#  19  constructorId    int64
#  20  number_x         object
#  21  grid             int64
#  22  position         object
#  23  positionOrder    int64
#  24  points           float64
#  25  laps             int64
#  26  time_y           object
#  27  milliseconds_x   object
#  28  fastestLap       object
#  29  rank             object
#  30  fastestLapTime   object
#  31  fastestLapSpeed  object
#  32  statusId         int64
#  33  surname          object
#  34  stop             int64
#  35  lap              int64
#  36  time             object
#  37  duration         object
#  38  milliseconds_y   int64
#  39  constructorRef   object
#  40  name             object
#  41  nationality      object
# dtypes: bool(5), float64(1), int64(17), object(19)
# memory usage: 3.1+ GB
